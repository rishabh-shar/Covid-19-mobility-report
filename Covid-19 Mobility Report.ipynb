# %% [markdown]
# # Global Mobility Report

# %% [markdown]
# This is the data taken from google which shows mobility of people before and after lockdown. This is a nice graphical representation of how actually Covid-19 affected my home state of Himachal Pradesh and also which state's residents were more responsible and which state's residents were not.

# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
gmr_df = pd.read_csv('Global_Mobility_Report.csv')
gmr_df.head()
# Out:
#   country_region_code        country_region sub_region_1 sub_region_2  \
# 0                  AE  United Arab Emirates          NaN          NaN
# 1                  AE  United Arab Emirates          NaN          NaN
# 2                  AE  United Arab Emirates          NaN          NaN
# 3                  AE  United Arab Emirates          NaN          NaN
# 4                  AE  United Arab Emirates          NaN          NaN
#
#   iso_3166_2_code  census_fips_code        date  \
# 0             NaN               NaN  2020-02-15
# 1             NaN               NaN  2020-02-16
# 2             NaN               NaN  2020-02-17
# 3             NaN               NaN  2020-02-18
# 4             NaN               NaN  2020-02-19
#
#    retail_and_recreation_percent_change_from_baseline  \
# 0                                                0.0
# 1                                                1.0
# 2                                               -1.0
# 3                                               -2.0
# 4                                               -2.0
#
#    grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                4.0
# 1                                                4.0
# 2                                                1.0
# 3                                                1.0
# 4                                                0.0
#
#    parks_percent_change_from_baseline  \
# 0                                 5.0
# 1                                 4.0
# 2                                 5.0
# 3                                 5.0
# 4                                 4.0
#
#    transit_stations_percent_change_from_baseline  \
# 0                                            0.0
# 1                                            1.0
# 2                                            1.0
# 3                                            0.0
# 4                                           -1.0
#
#    workplaces_percent_change_from_baseline  \
# 0                                      2.0
# 1                                      2.0
# 2                                      2.0
# 3                                      2.0
# 4                                      2.0
#
#    residential_percent_change_from_baseline
# 0                                       1.0
# 1                                       1.0
# 2                                       1.0
# 3                                       1.0
# 4                                       1.0

# %%
categories_google_mobility = ['retail_and_recreation_percent_change_from_baseline',
 'grocery_and_pharmacy_percent_change_from_baseline',
 'parks_percent_change_from_baseline',
 'transit_stations_percent_change_from_baseline',
 'workplaces_percent_change_from_baseline',
 'residential_percent_change_from_baseline']
categories_google_mobility
# Out:
# ['retail_and_recreation_percent_change_from_baseline',
#  'grocery_and_pharmacy_percent_change_from_baseline',
#  'parks_percent_change_from_baseline',
#  'transit_stations_percent_change_from_baseline',
#  'workplaces_percent_change_from_baseline',
#  'residential_percent_change_from_baseline']

# %%
# let's get a subset of data from Himachal Pradesh, India
country = 'India'
region = 'Himachal Pradesh'
sub_df = gmr_df[(gmr_df['country_region']== country) & (gmr_df['sub_region_1']==region)]
sub_df.loc[:,'date'] = pd.to_datetime(sub_df.loc[:,'date'])
sub_df = sub_df.sort_values('date', ascending=True)

 
# let's plot all time series for this region
for group in categories_google_mobility:
    print(group)
     
    fig, ax = plt.subplots(figsize=(16, 4))
    plt.plot(sub_df['date'], sub_df[group], label=group)
    ax.axhline(y=0, color='gray')
    ax.axvline(pd.to_datetime('2020-03-10'), color='r', linestyle='--', lw=2)
    plt.title(country + ' '+ region + ': ' + group)
    plt.legend(loc='best') 
    plt.grid()
    plt.show()
# Out:
# retail_and_recreation_percent_change_from_baseline
# grocery_and_pharmacy_percent_change_from_baseline
# parks_percent_change_from_baseline
# transit_stations_percent_change_from_baseline
# workplaces_percent_change_from_baseline
# residential_percent_change_from_baseline

# %%
sub_df = gmr_df[(gmr_df['country_region']=='India')]
sub_df.loc[:,'date'] = pd.to_datetime(sub_df.loc[:,'date'])
sub_df = sub_df.sort_values('date', ascending=True)
sub_df.head()
# Out:
#        country_region_code country_region sub_region_1 sub_region_2  \
# 96909                   IN          India          NaN          NaN
# 99571                   IN          India      Manipur          NaN
# 97635                   IN          India   Chandigarh          NaN
# 100660                  IN          India   Tamil Nadu          NaN
# 98845                   IN          India    Jharkhand          NaN
#
#        iso_3166_2_code  census_fips_code       date  \
# 96909              NaN               NaN 2020-02-15
# 99571            IN-MN               NaN 2020-02-15
# 97635            IN-CH               NaN 2020-02-15
# 100660           IN-TN               NaN 2020-02-15
# 98845            IN-JH               NaN 2020-02-15
#
#         retail_and_recreation_percent_change_from_baseline  \
# 96909                                                 1.0
# 99571                                                 1.0
# 97635                                                 0.0
# 100660                                                1.0
# 98845                                                -1.0
#
#         grocery_and_pharmacy_percent_change_from_baseline  \
# 96909                                                 2.0
# 99571                                                -1.0
# 97635                                                 0.0
# 100660                                                0.0
# 98845                                                -1.0
#
#         parks_percent_change_from_baseline  \
# 96909                                  3.0
# 99571                                  2.0
# 97635                                  8.0
# 100660                                 3.0
# 98845                                  2.0
#
#         transit_stations_percent_change_from_baseline  \
# 96909                                             3.0
# 99571                                             7.0
# 97635                                             4.0
# 100660                                            2.0
# 98845                                             4.0
#
#         workplaces_percent_change_from_baseline  \
# 96909                                       5.0
# 99571                                      -9.0
# 97635                                       5.0
# 100660                                      6.0
# 98845                                       6.0
#
#         residential_percent_change_from_baseline
# 96909                                        0.0
# 99571                                        2.0
# 97635                                       -1.0
# 100660                                       0.0
# 98845                                        0.0

# %%
last_state_df = sub_df[sub_df['sub_region_2'].isna()].groupby(['sub_region_1']).mean().reset_index()

for group in categories_google_mobility:
    print(group)
    min_dt = last_state_df[last_state_df[group]== last_state_df[['sub_region_1', group]][group].min()]
    max_dt = last_state_df[last_state_df[group]== last_state_df[['sub_region_1', group]][group].max()]
    
    fig, ax = plt.subplots(figsize=(16, 4))
    
    plt.plot(sub_df[(sub_df['sub_region_1'] == min_dt['sub_region_1'].values[0]) 
           & (sub_df['sub_region_2'].isna() )]['date'], 
             sub_df[(sub_df['sub_region_1'] ==  min_dt['sub_region_1'].values[0]) 
           & (sub_df['sub_region_2'].isna() )][group], label='Best: ' +  min_dt['sub_region_1'].values[0])
    plt.plot(sub_df[(sub_df['sub_region_1'] == max_dt['sub_region_1'].values[0]) 
            & (sub_df['sub_region_2'].isna() )]['date'], 
             sub_df[(sub_df['sub_region_1'] == max_dt['sub_region_1'].values[0]) 
            & (sub_df['sub_region_2'].isna() )][group], label='Worst: ' + max_dt['sub_region_1'].values[0])


    ax.axhline(y=0, color='gray')
    #ax.axvline(pd.to_datetime('2020-03-10'), color='r', linestyle='--', lw=2)
    plt.title('Best & Worst ' + group)
    plt.legend(loc='best') 
    plt.grid()
    plt.show()
# Out:
# retail_and_recreation_percent_change_from_baseline
# grocery_and_pharmacy_percent_change_from_baseline
# parks_percent_change_from_baseline
# transit_stations_percent_change_from_baseline
# workplaces_percent_change_from_baseline
# residential_percent_change_from_baseline
